# %% [markdown]
# <a href="https://colab.research.google.com/github/m10923039/DM/blob/main/adult_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/31_DM/adult.data", header=None)
df.columns=["age",
      "workclass",
      "fnlwgt",
      "education",
      "education_num",
      "marital_status",
      "occupation",
      "relationship",
      "race",
      "sex",
      "capital_gain",
      "capital_loss",
      "hours_per_week",
      "native_country",
      "salary"
      ]
df
# Out:
#        age          workclass  fnlwgt  ... hours_per_week  native_country  salary
# 0       39          State-gov   77516  ...             40   United-States   <=50K
# 1       50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2       38            Private  215646  ...             40   United-States   <=50K
# 3       53            Private  234721  ...             40   United-States   <=50K
# 4       28            Private  338409  ...             40            Cuba   <=50K
# ...    ...                ...     ...  ...            ...             ...     ...
# 32556   27            Private  257302  ...             38   United-States   <=50K
# 32557   40            Private  154374  ...             40   United-States    >50K
# 32558   58            Private  151910  ...             40   United-States   <=50K
# 32559   22            Private  201490  ...             20   United-States   <=50K
# ...

# %%
# 清除不必要欄位
# education_num
df=df.drop(['education_num'],axis=1)

# %%
# 判斷有缺失值的欄位 ' ?' 
for column in df.columns:
  if (df[column].value_counts().index==' ?').any():
    print(column)
# Out:
# workclass
# occupation
# native_country

# %%
# 刪除缺失值的資料
fliter1 = (df["native_country"] != ' ?')
fliter2 = (df["occupation"] != ' ?')
fliter3 = (df["workclass"] != ' ?')
df_1 = df[fliter1 & fliter2 & fliter3]
df_1
# Out:
#        age          workclass  fnlwgt  ... hours_per_week  native_country  salary
# 0       39          State-gov   77516  ...             40   United-States   <=50K
# 1       50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2       38            Private  215646  ...             40   United-States   <=50K
# 3       53            Private  234721  ...             40   United-States   <=50K
# 4       28            Private  338409  ...             40            Cuba   <=50K
# ...    ...                ...     ...  ...            ...             ...     ...
# 32556   27            Private  257302  ...             38   United-States   <=50K
# 32557   40            Private  154374  ...             40   United-States    >50K
# 32558   58            Private  151910  ...             40   United-States   <=50K
# 32559   22            Private  201490  ...             20   United-States   <=50K
# ...

# %%
# salary 注意 ' <=50K' 有空格
# <=50K 編為0
# >50K 編為1

df_1.loc[df_1.loc[:,'salary']==' <=50K','salary']=0
df_1.loc[df_1['salary']==' >50K','salary']=1

# sex 
# Male 編為0
# Female 編為1

df_1.loc[df_1['sex']==' Male','sex']=0
df_1.loc[df_1['sex']==' Female','sex']=1

df_1[['salary','sex']]=df_1[['salary','sex']].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_1
# Out:
#        age          workclass  fnlwgt  ... hours_per_week  native_country salary
# 0       39          State-gov   77516  ...             40   United-States      0
# 1       50   Self-emp-not-inc   83311  ...             13   United-States      0
# 2       38            Private  215646  ...             40   United-States      0
# 3       53            Private  234721  ...             40   United-States      0
# 4       28            Private  338409  ...             40            Cuba      0
# ...    ...                ...     ...  ...            ...             ...    ...
# 32556   27            Private  257302  ...             38   United-States      0
# 32557   40            Private  154374  ...             40   United-States      1
# 32558   58            Private  151910  ...             40   United-States      0
# 32559   22            Private  201490  ...             20   United-States      0
# 32560   52       Self-emp-inc  287927  ...             40   United-States      1
#
# ...

# %%
data=pd.get_dummies(df_1)
data
# Out:
#        age  fnlwgt  ...  native_country_ Vietnam  native_country_ Yugoslavia
# 0       39   77516  ...                        0                           0
# 1       50   83311  ...                        0                           0
# 2       38  215646  ...                        0                           0
# 3       53  234721  ...                        0                           0
# 4       28  338409  ...                        0                           0
# ...    ...     ...  ...                      ...                         ...
# 32556   27  257302  ...                        0                           0
# 32557   40  154374  ...                        0                           0
# 32558   58  151910  ...                        0                           0
# 32559   22  201490  ...                        0                           0
# 32560   52  287927  ...                        0                           0
#
# [30162 rows x 103 columns]

# %% [markdown]
# # 輸入 X (salary)
# *   age
# *   fnlwgt
# *   ....
#
# # 輸出 Y
# *   salary

# %%
x=data.drop('salary',axis=1)
y=data['salary'].to_frame()

# %%
x
# Out:
#        age  fnlwgt  ...  native_country_ Vietnam  native_country_ Yugoslavia
# 0       39   77516  ...                        0                           0
# 1       50   83311  ...                        0                           0
# 2       38  215646  ...                        0                           0
# 3       53  234721  ...                        0                           0
# 4       28  338409  ...                        0                           0
# ...    ...     ...  ...                      ...                         ...
# 32556   27  257302  ...                        0                           0
# 32557   40  154374  ...                        0                           0
# 32558   58  151910  ...                        0                           0
# 32559   22  201490  ...                        0                           0
# 32560   52  287927  ...                        0                           0
#
# [30162 rows x 102 columns]

# %%
y
# Out:
#        salary
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 32556       0
# 32557       1
# 32558       0
# 32559       0
# 32560       1
#
# [30162 rows x 1 columns]

# %% [markdown]
# # 切割資料集

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x, y, test_size=0.3, random_state=52)

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dt.get_depth()
# Out:
# 45

# %%
dt.get_n_leaves()
# Out:
# 3126

# %% [markdown]
# # 處理測試資料集
# 動作與步驟與訓練資料集一樣

# %%
# /content/drive/MyDrive/Colab Notebooks/31_DM/adult.test
# 處理測試資料集
df_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/31_DM/adult.test", header=None)
df_test.columns=["age",
      "workclass",
      "fnlwgt",
      "education",
      "education_num",
      "marital_status",
      "occupation",
      "relationship",
      "race",
      "sex",
      "capital_gain",
      "capital_loss",
      "hours_per_week",
      "native_country",
      "salary"
      ]
df_test
# Out:
#        age      workclass  fnlwgt  ... hours_per_week  native_country   salary
# 0       25        Private  226802  ...             40   United-States   <=50K.
# 1       38        Private   89814  ...             50   United-States   <=50K.
# 2       28      Local-gov  336951  ...             40   United-States    >50K.
# 3       44        Private  160323  ...             40   United-States    >50K.
# 4       18              ?  103497  ...             30   United-States   <=50K.
# ...    ...            ...     ...  ...            ...             ...      ...
# 16276   39        Private  215419  ...             36   United-States   <=50K.
# 16277   64              ?  321403  ...             40   United-States   <=50K.
# 16278   38        Private  374983  ...             50   United-States   <=50K.
# 16279   44        Private   83891  ...             40   United-States   <=50K.
# 16280   35   Self-emp-inc  182148  ...             60   United-States    >50K.
#
# ...

# %%
# 清除不必要欄位
# education_num
df_test=df_test.drop(['education_num'],axis=1)
# 判斷有缺失值的欄位 ' ?' 
fliter_list=[]
for column in df_test.columns:
  if (df_test[column].value_counts().index==' ?').any():
    fliter_list.append(column)
# 刪除缺失值的資料
df_test=df_test[(df_test[fliter_list]!=' ?').all(axis=1)]

# %%
# salary 注意 ' <=50K.' 有空格 and 最後有點
# <=50K 編為0
# >50K 編為1

df_test.loc[df_test.loc[:,'salary']==' <=50K.','salary']=0
df_test.loc[df_test['salary']==' >50K.','salary']=1

# sex 
# Male 編為0
# Female 編為1

df_test.loc[df_test['sex']==' Male','sex']=0
df_test.loc[df_test['sex']==' Female','sex']=1
df_test
# Out:
#        age      workclass  fnlwgt  ... hours_per_week  native_country salary
# 0       25        Private  226802  ...             40   United-States      0
# 1       38        Private   89814  ...             50   United-States      0
# 2       28      Local-gov  336951  ...             40   United-States      1
# 3       44        Private  160323  ...             40   United-States      1
# 5       34        Private  198693  ...             30   United-States      0
# ...    ...            ...     ...  ...            ...             ...    ...
# 16275   33        Private  245211  ...             40   United-States      0
# 16276   39        Private  215419  ...             36   United-States      0
# 16278   38        Private  374983  ...             50   United-States      0
# 16279   44        Private   83891  ...             40   United-States      0
# 16280   35   Self-emp-inc  182148  ...             60   United-States      1
#
# [15060 rows x 14 columns]

# %%
df_test[['salary','sex']]=df_test[['salary','sex']].astype(int)
df_test_data=pd.get_dummies(df_test)
add_list=list(set(data.columns)-set(df_test_data.columns))
df_test_data[add_list]=0
df_test_data
# Out:
#        age  ...  native_country_ Holand-Netherlands
# 0       25  ...                                   0
# 1       38  ...                                   0
# 2       28  ...                                   0
# 3       44  ...                                   0
# 5       34  ...                                   0
# ...    ...  ...                                 ...
# 16275   33  ...                                   0
# 16276   39  ...                                   0
# 16278   38  ...                                   0
# 16279   44  ...                                   0
# 16280   35  ...                                   0
#
# [15060 rows x 103 columns]

# %%
# 測試資料集
X_test=df_test_data.drop('salary',axis=1)
Y_test=df_test_data['salary'].to_frame()

# %% [markdown]
# # 績效計算

# %%
def scoring(clf, X, y):
    y_pred = clf.predict(X)
    accuracy = accuracy_score(y_true=y, y_pred=y_pred)
    precision = precision_score(y_true=y, y_pred=y_pred)
    recall = recall_score(y_true=y, y_pred=y_pred)
    f1 = f1_score(y_true=y, y_pred=y_pred)
    return pd.DataFrame.from_dict(data={"accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            }, orient='index').T
train_score = scoring(dt, X_train, Y_train)
train_score
# Out:
#    accuracy  precision   recall        f1
# 0  0.999953        1.0  0.99981  0.999905

# %%
val_score = scoring(dt, X_val,Y_val)
val_score
# Out:
#    accuracy  precision    recall        f1
# 0  0.810697   0.611991  0.639088  0.625246

# %%
test_score = scoring(dt, X_test,Y_test)
test_score
# Out:
#    accuracy  precision    recall        f1
# 0  0.784595    0.55486  0.623243  0.587067

# %% [markdown]
# # 畫混淆矩陣

# %%
from sklearn.metrics import ConfusionMatrixDisplay
def plot_confusion_matrix(clf, X, y):
  y_pred = clf.predict(X)
  np_confusion_matrix=confusion_matrix(y_true=y, y_pred=y_pred)
  confusionMatrixDisplay = ConfusionMatrixDisplay(confusion_matrix=np_confusion_matrix,display_labels=clf.classes_)
  fig, ax = plt.subplots(figsize=(12,9))
  plt.rcParams.update({'font.size': 16})
  plt.xticks(fontsize=16)
  plt.yticks(fontsize=16)
  confusionMatrixDisplay.plot(ax=ax,values_format='.5g')
  plt.show()
plot_confusion_matrix(dt, X_train, Y_train)

# %%
plot_confusion_matrix(dt, X_val, Y_val)

# %%
plot_confusion_matrix(dt, X_test, Y_test)

# %% [markdown]
# # 輸出excel

# %%
y_pred=dt.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
df_out_file=pd.DataFrame(y_pred,columns=['pred'])
df_out_file['true']=Y_test.to_numpy()
df_out_file
# Out:
#        pred  true
# 0         0     0
# 1         1     0
# 2         1     1
# 3         1     1
# 4         0     0
# ...     ...   ...
# 15055     0     0
# 15056     0     0
# 15057     1     0
# 15058     0     0
# 15059     1     1
#
# [15060 rows x 2 columns]

# %%
df_out_file.to_excel('/content/drive/MyDrive/Colab Notebooks/31_DM/adult_result.xlsx')

# %% [markdown]
# # 作業第四點

# %%
dt.get_n_leaves()
# Out:
# 3126

# %%
dt.get_depth()
# Out:
# 45

# %%
dt_list=[]
max_depth=dt.get_depth()
max_leaf_nodes=dt.get_n_leaves()
max_leaf_nodes_range=range(200,max_leaf_nodes+1,200)
for depth in max_leaf_nodes_range:
  dt_temp = DecisionTreeClassifier(max_leaf_nodes =max_leaf_nodes,max_depth=depth)
  dt_temp.fit(X_train, Y_train)
  dt_list.append(dt_temp)

# %%
train_scores = [dt_temp.score(X_train, Y_train) for dt_temp in dt_list]
val_scores = [dt_temp.score(X_val, Y_val) for dt_temp in dt_list]
test_scores = [dt_temp.score(X_test, Y_test) for dt_temp in dt_list]


fig, ax = plt.subplots(figsize=(18,9))
ax.set_xlabel("max_leaf_nodes")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs max_leaf_nodes for training Validation and testing sets")
ax.set_xlim((0,max_leaf_nodes_range.stop))

#x軸的刻度間隔設置為200
x_major_locator=plt.MultipleLocator(200)
#把x軸的主刻度設置為200的倍數
ax.xaxis.set_major_locator(x_major_locator)
fig.autofmt_xdate(rotation=45)

ax.plot(max_leaf_nodes_range, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(max_leaf_nodes_range, val_scores, marker='x', label="val",
        drawstyle="steps-post")
ax.plot(max_leaf_nodes_range, test_scores, marker='D', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()
